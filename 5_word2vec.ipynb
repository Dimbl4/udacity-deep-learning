# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /home/dmitry/.pyenv/versions/3.6.3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
        statinfo = os.stat(filename)
    else:
        statinfo = os.stat(filename)
        
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.996813
# Nearest to american: touma, voiceless, khaki, ensembles, prices, inherits, twisting, nebraska,
# Nearest to united: kala, subplot, tabloids, cat, conglomerate, stark, trowa, massive,
# Nearest to called: goes, jinx, fretless, alkene, subjugating, nicht, molds, ces,
# Nearest to to: autocephalous, join, tong, suitability, bock, thirsty, magdalene, curdled,
# Nearest to years: alarc, ilp, weaponry, imperfectly, ashore, zoot, intestine, engel,
# Nearest to if: surfin, domestically, piped, obsidian, nadi, believable, areas, honesty,
# Nearest to known: germs, py, udi, hg, grass, privatizing, rejoined, orpheus,
# Nearest to and: keating, sizeable, predictable, jacks, filipino, preregular, existentialists, chest,
# Nearest to other: deprogramming, transferring, aman, renovation, molecule, catchy, reasoned, pringle,
# Nearest to six: relapse, damnation, flu, centric, argue, mountainous, ensembles, joaquim,
# Nearest to when: selfless, canonization, ramos, swanson, shaitan, abjads, mothers, along,
# Nearest to who: needlessly, kou, hire, biologically, crawford, populations, truer, agitation,
# Nearest to than: hirohito, learners, yazoo, globally, franklin, antarctica, gianfranco, loran,
# Nearest to two: privateer, anhydride, cutoff, mycenaean, uz, shaitan, gustave, skeletal,
# Nearest to state: mujahedin, unlawful, yuan, occultists, tosses, elsewhere, ratites, alison,
# Nearest to that: stoke, uucp, shillings, formalized, decoder, cessation, deleterious, boo,
# Average loss at step 2000: 4.365919
# Average loss at step 4000: 3.867594
# Average loss at step 6000: 3.791066
# Average loss at step 8000: 3.693482
# Average loss at step 10000: 3.616442
# Nearest to american: candidiasis, rrez, bauhaus, municipalities, touma, enlisting, idiopathic, aggressor,
# Nearest to united: subplot, kala, expendable, tabloids, leans, agnostic, pokemon, haircut,
# Nearest to called: swore, exploitation, baptise, rations, jinx, narcissus, nicht, occupiers,
# Nearest to to: would, not, autocephalous, can, we, indignation, magdalene, drab,
# Nearest to years: ilp, alarc, weaponry, intestine, imperfectly, cover, rackham, zoot,
# Nearest to if: can, forged, obsidian, domestically, piped, believable, flowered, areas,
# Nearest to known: py, vinton, hana, collett, bh, a, nmt, skirt,
# Nearest to and: or, in, of, b, d, s, breton, prince,
# Nearest to other: reasoned, repeaters, renovation, areas, many, antennas, symmes, nihon,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to when: angola, until, along, sargent, gpmg, sometime, frieze, mise,
# Nearest to who: he, kou, they, visualize, ones, been, and, carcassonne,
# Nearest to than: learners, antarctica, gianfranco, dunlop, franklin, laertes, pasteurization, neuronal,
# Nearest to two: three, five, four, six, seven, one, eight, nine,
# Nearest to state: colspan, mujahedin, sanctification, tosses, tetrahedra, unlawful, about, variable,
# Nearest to that: what, it, which, undergone, this, stoke, prisons, tables,
# Average loss at step 12000: 3.602147
# Average loss at step 14000: 3.567388
# Average loss at step 16000: 3.405435
# Average loss at step 18000: 3.462756
# Average loss at step 20000: 3.539627
# Nearest to american: australian, french, idiopathic, decency, municipalities, cinderella, rightist, dutch,
# Nearest to united: subplot, kala, expendable, leans, tabloids, pokemon, haircut, rhead,
# Nearest to called: nicht, jitsu, und, heysel, contemplation, endorsing, frenchman, narcissus,
# Nearest to to: would, will, not, autocephalous, homesick, spink, can, inaction,
# Nearest to years: days, cover, ilp, alarc, diamond, imperfectly, wff, miyazaki,
# Nearest to if: where, can, but, flowered, should, hopped, forged, rowboat,
# Nearest to known: collett, henchmen, py, bh, northward, understood, such, vinton,
# Nearest to and: or, but, raskin, canning, in, excite, braxton, floating,
# Nearest to other: many, some, antennas, reasoned, areas, these, ventral, various,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to when: until, where, along, was, since, after, but, mise,
# Nearest to who: he, which, they, she, often, visualize, kou, been,
# Nearest to than: or, learners, pasteurization, hirohito, gianfranco, dunlop, commercials, argument,
# Nearest to two: five, three, four, six, eight, seven, one, nine,
# Nearest to state: colspan, tetrahedra, unlawful, afternoons, noah, sanctification, mujahedin, ratites,
# Nearest to that: which, what, but, because, undergone, subplot, stoke, sprouted,
# Average loss at step 22000: 3.496811
# Average loss at step 24000: 3.492048
# Average loss at step 26000: 3.485301
# Average loss at step 28000: 3.479352
# Average loss at step 30000: 3.501388
# Nearest to american: australian, french, english, german, british, dutch, national, canadian,
# Nearest to united: kala, subplot, expendable, tabloids, pokemon, leans, rhead, haircut,
# Nearest to called: heysel, und, nicht, avl, used, electroweak, grim, see,
# Nearest to to: would, magdalene, can, autocephalous, will, emery, not, refered,
# Nearest to years: days, cover, minutes, ilp, alarc, pflp, bases, imperfectly,
# Nearest to if: when, where, however, but, can, should, though, sailplane,
# Nearest to known: used, regarded, such, henchmen, well, understood, seen, kept,
# Nearest to and: or, in, but, jr, who, from, by, against,
# Nearest to other: various, those, these, some, many, areas, ventral, enumerative,
# Nearest to six: eight, seven, nine, four, five, three, zero, two,
# Nearest to when: where, if, after, during, until, although, but, bottling,
# Nearest to who: he, they, she, which, and, kou, often, there,
# Nearest to than: learners, or, pasteurization, reith, gianfranco, much, dunlop, commercials,
# Nearest to two: three, one, four, five, six, seven, eight, nine,
# Nearest to state: colspan, tetrahedra, city, sanctification, features, noah, discreetly, afternoons,
# Nearest to that: which, what, however, because, undergone, this, but, stoke,
# Average loss at step 32000: 3.500289
# Average loss at step 34000: 3.493413
# Average loss at step 36000: 3.457338
# Average loss at step 38000: 3.303797
# Average loss at step 40000: 3.430590
# Nearest to american: australian, german, british, french, clap, saintly, english, national,
# Nearest to united: tabloids, kala, subplot, expendable, rhead, leans, pokemon, haircut,
# Nearest to called: und, considered, grim, see, nicht, used, baptise, heysel,
# Nearest to to: will, would, autocephalous, can, must, could, adverbs, for,
# Nearest to years: days, minutes, imperfectly, alarc, bases, pflp, investigator, prokaryote,
# Nearest to if: where, when, is, hopped, though, sailplane, goldfinger, can,
# Nearest to known: used, such, regarded, well, remembered, understood, henchmen, diphthongs,
# Nearest to and: or, but, like, e, institutionalized, while, in, emitters,
# Nearest to other: various, many, those, schlick, several, antennas, brazilian, enumerative,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to when: if, after, where, during, before, although, was, until,
# Nearest to who: he, which, she, they, often, kou, also, visualize,
# Nearest to than: or, much, reith, learners, pasteurization, fansite, commercials, gianfranco,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to state: colspan, noah, city, unlawful, tetrahedra, shout, sanctification, warez,
# Nearest to that: which, what, this, however, undergone, because, it, bayer,
# Average loss at step 42000: 3.434763
# Average loss at step 44000: 3.453158
# Average loss at step 46000: 3.448141
# Average loss at step 48000: 3.358471
# Average loss at step 50000: 3.379394
# Nearest to american: australian, french, british, irish, english, clap, saintly, assaulting,
# Nearest to united: tabloids, subplot, kala, expendable, rhead, haircut, pokemon, conglomerate,
# Nearest to called: und, see, grim, baptise, nicht, heysel, emotions, avl,
# Nearest to to: could, would, autocephalous, will, may, homesick, isaias, should,
# Nearest to years: days, minutes, bases, alarc, imperfectly, cover, year, investigator,
# Nearest to if: when, where, though, before, while, although, is, yvonne,
# Nearest to known: used, regarded, such, well, remembered, understood, seen, defined,
# Nearest to and: or, but, of, while, including, however, in, rah,
# Nearest to other: various, many, those, several, some, cues, these, vitally,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to when: if, where, after, while, before, although, during, though,
# Nearest to who: he, which, she, they, stacey, galactica, have, kou,
# Nearest to than: or, much, reith, learners, fasces, fansite, even, hessian,
# Nearest to two: three, one, four, six, five, eight, seven, nine,
# Nearest to state: noah, colspan, sanctification, unlawful, warez, advent, conceding, tetrahedra,
# Nearest to that: which, however, what, undergone, forgo, convergent, but, this,
# Average loss at step 52000: 3.437734
# Average loss at step 54000: 3.427363
# Average loss at step 56000: 3.437605
# Average loss at step 58000: 3.396066
# Average loss at step 60000: 3.389471
# Nearest to american: australian, british, french, german, african, english, irish, clap,
# Nearest to united: following, kala, subplot, tabloids, haircut, rhead, expendable, leans,
# Nearest to called: considered, used, overwhelmed, driftwood, grim, nicht, known, avl,
# Nearest to to: would, aquilonia, autocephalous, magdalene, will, could, isaias, may,
# Nearest to years: days, minutes, centuries, months, year, times, decades, weeks,
# Nearest to if: when, where, though, before, although, because, then, goldfinger,
# Nearest to known: used, regarded, remembered, well, such, defined, seen, considered,
# Nearest to and: or, but, although, than, for, while, tunnelling, oxidant,
# Nearest to other: various, many, those, several, more, different, including, cues,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to when: if, although, after, before, while, during, however, where,
# Nearest to who: he, which, she, they, often, kou, now, already,
# Nearest to than: or, much, reith, and, but, donoghue, pasteurization, learners,
# Nearest to two: three, four, five, one, six, eight, seven, zero,
# Nearest to state: noah, city, colspan, tetrahedra, advent, government, activating, conceding,
# Nearest to that: which, what, undergone, this, however, danes, it, forgo,
# Average loss at step 62000: 3.245837
# Average loss at step 64000: 3.254144
# Average loss at step 66000: 3.403508
# Average loss at step 68000: 3.395435
# Average loss at step 70000: 3.360240
# Nearest to american: british, australian, french, irish, african, german, assaulting, banking,
# Nearest to united: subplot, kala, following, haircut, tabloids, rhead, sofia, expendable,
# Nearest to called: heysel, considered, driftwood, known, evangelicalism, named, accepts, tenths,
# Nearest to to: would, will, must, autocephalous, can, aquilonia, could, may,
# Nearest to years: days, months, minutes, decades, weeks, centuries, times, year,
# Nearest to if: when, where, though, before, although, however, because, without,
# Nearest to known: used, regarded, such, remembered, defined, seen, well, considered,
# Nearest to and: or, while, but, which, tunnelling, like, rah, however,
# Nearest to other: various, many, some, different, others, several, those, pid,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Nearest to when: if, however, where, while, before, although, after, because,
# Nearest to who: he, she, they, often, caching, kou, rebounds, which,
# Nearest to than: or, while, much, reith, but, afghana, fansite, pasteurization,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to state: city, colspan, government, noah, states, defunct, janitor, richelieu,
# Nearest to that: which, what, however, but, this, undergone, because, usually,
# Average loss at step 72000: 3.372300
# Average loss at step 74000: 3.347510
# Average loss at step 76000: 3.316065
# Average loss at step 78000: 3.356629
# Average loss at step 80000: 3.378963
# Nearest to american: british, french, assaulting, australian, irish, national, german, koan,
# Nearest to united: subplot, kala, following, haircut, tabloids, rhead, pedagogy, expendable,
# Nearest to called: considered, known, used, evangelicalism, named, driftwood, radiating, fiftieth,
# Nearest to to: autocephalous, spink, isaias, magdalene, earned, loa, will, must,
# Nearest to years: days, months, minutes, decades, weeks, year, times, centuries,
# Nearest to if: when, though, where, before, although, during, then, after,
# Nearest to known: used, regarded, remembered, such, defined, seen, considered, called,
# Nearest to and: or, but, while, dandelion, tunnelling, including, partridge, surinam,
# Nearest to other: various, others, those, many, several, some, purcell, hajj,
# Nearest to six: five, four, eight, seven, three, nine, two, zero,
# Nearest to when: after, before, during, although, where, if, while, though,
# Nearest to who: often, he, she, they, kou, never, usually, accessories,
# Nearest to than: while, much, or, fansite, wealthier, but, reith, birley,
# Nearest to two: three, four, six, five, seven, one, eight, isbn,
# Nearest to state: city, quarterfinals, states, colspan, usa, noah, sponsoring, protections,
# Nearest to that: which, however, what, naguib, danes, undergone, this, steadman,
# Average loss at step 82000: 3.401392
# Average loss at step 84000: 3.409739
# Average loss at step 86000: 3.390754
# Average loss at step 88000: 3.355269
# Average loss at step 90000: 3.365148
# Nearest to american: british, australian, french, assaulting, national, irish, koan, german,
# Nearest to united: following, subplot, kala, haircut, expendable, rhead, tabloids, pedagogy,
# Nearest to called: considered, named, used, known, able, electroweak, suitably, floods,
# Nearest to to: will, would, must, autocephalous, pegasus, isaias, could, should,
# Nearest to years: days, months, decades, minutes, centuries, weeks, year, times,
# Nearest to if: when, where, though, before, although, after, however, so,
# Nearest to known: used, regarded, such, remembered, seen, defined, well, understood,
# Nearest to and: or, but, while, ghaznavid, including, in, disdained, partridge,
# Nearest to other: various, others, different, purcell, private, most, calypso, those,
# Nearest to six: eight, seven, five, nine, four, three, zero, two,
# Nearest to when: after, before, if, although, while, where, during, though,
# Nearest to who: he, she, often, which, they, but, already, probably,
# Nearest to than: reith, afghana, fansite, or, rajons, much, fruity, wealthier,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to state: city, noah, protections, activating, colspan, quarterfinals, thant, sponsoring,
# Nearest to that: which, however, what, but, danes, hamming, forgo, stoke,
# Average loss at step 92000: 3.396671
# Average loss at step 94000: 3.254505
# Average loss at step 96000: 3.358041
# Average loss at step 98000: 3.243800
# Average loss at step 100000: 3.355103
# Nearest to american: british, australian, japanese, cpi, french, irish, assaulting, halos,
# Nearest to united: following, subplot, kala, haircut, tabloids, expendable, rhead, sofia,
# Nearest to called: named, considered, used, known, referred, corey, colourless, suitably,
# Nearest to to: could, will, must, should, can, would, autocephalous, jumblatt,
# Nearest to years: days, months, year, decades, minutes, centuries, weeks, times,
# Nearest to if: when, where, though, before, although, because, without, after,
# Nearest to known: regarded, such, used, defined, remembered, seen, considered, possible,
# Nearest to and: or, but, including, while, although, partridge, of, dandelion,
# Nearest to other: various, others, different, purcell, places, specific, alternative, pid,
# Nearest to six: four, eight, seven, five, nine, three, two, zero,
# Nearest to when: if, while, where, after, before, although, though, during,
# Nearest to who: he, she, which, also, never, still, that, probably,
# Nearest to than: or, reith, afghana, while, much, fansite, wealthier, and,
# Nearest to two: four, three, six, five, seven, eight, one, nine,
# Nearest to state: city, noah, protections, sparking, snipers, colspan, richelieu, tavola,
# Nearest to that: which, what, however, this, danes, who, convergent, how,
# CPU times: user 13min 48s, sys: 23.9 s, total: 14min 12s
# Wall time: 12min 8s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_bag, bag_window):
    global data_index
    assert num_bag <= 2 * bag_window
    batch = np.ndarray(shape=(batch_size, num_bag), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * bag_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        target = bag_window
        buffer_without_target = buffer.copy()
        buffer_without_target.remove(buffer[target])
        for j, index in enumerate(np.random.choice(buffer_without_target, size=num_bag, replace=False)):
            batch[i, j] = index
            labels[i, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        

    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_bag, bag_window in [(2, 1), (3, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, num_bag=num_bag, bag_window=bag_window)
    print('\nwith num_bag = {} and bag_window = {}:'.format(num_bag, bag_window))
    for bi, label in zip(batch, labels):
        print("target/context: {}\t{}".format(reverse_dictionary[label[0]],
                                              [reverse_dictionary[bi] for bi in bi]))
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_bag = 2 and bag_window = 1:
# target/context: originated	['as', 'anarchism']
# target/context: as	['a', 'originated']
# target/context: a	['term', 'as']
# target/context: term	['of', 'a']
#
# with num_bag = 3 and bag_window = 2:
# target/context: as	['anarchism', 'originated', 'term']
# target/context: a	['term', 'of', 'as']
# target/context: term	['a', 'as', 'of']
# target/context: of	['term', 'a', 'abuse']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
num_bag = 2 # How many words will be associated with the target word.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_bag])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.

    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_bag, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.399859
# Nearest to if: abitibi, nasser, abbas, apogee, textbook, writable, lar, shermer,
# Nearest to all: robbers, romanis, wavelet, salome, alkoxide, pantomime, representational, pigeons,
# Nearest to called: honshu, stroud, carvings, uneconomic, jacob, aire, sst, fh,
# Nearest to new: america, subjected, natal, quranic, auroral, inlay, nile, chat,
# Nearest to there: purges, bunyan, outward, negating, rothschild, policies, chilling, regularity,
# Nearest to also: simone, trang, brews, counterexamples, rivera, emphasizes, hesse, transgendered,
# Nearest to with: lycaon, golden, strathclyde, urartu, claypool, consigned, mychal, urn,
# Nearest to a: wildlife, aubier, xinjiang, randi, larva, nintendo, arminius, arabidopsis,
# Nearest to such: pesticide, herbs, broccoli, turbocharger, bump, knud, fei, magnum,
# Nearest to can: infects, freshness, everyman, obtained, bright, natural, romney, fortified,
# Nearest to nine: confrontational, museu, ethically, confrontation, budo, hannover, khomeini, division,
# Nearest to their: guiana, apocalypse, aldosterone, sesotho, midwifery, barn, keying, desire,
# Nearest to during: shutdown, turbine, crocodiles, tessellations, comedians, taxon, nuisance, galvani,
# Nearest to be: lumpur, cta, genesee, contingent, troyes, associations, disciples, groening,
# Nearest to united: sparring, skilful, wavetable, explorers, refugees, vied, yyyy, anaximander,
# Nearest to i: concession, nand, gag, grendel, memorable, watercolors, twinned, become,
# Average loss at step 2000: 4.097405
# Average loss at step 4000: 3.557913
# Average loss at step 6000: 3.382385
# Average loss at step 8000: 3.243058
# Average loss at step 10000: 3.175275
# Nearest to if: abbas, apogee, abitibi, screenshots, cis, when, noted, asterix,
# Nearest to all: forcing, khmer, lucius, maynard, apollinaire, cheesemaking, inferiority, begging,
# Nearest to called: quarks, honshu, simile, reflectivity, jacob, alkyl, represents, tyson,
# Nearest to new: america, badge, campaigners, auroral, natal, inlay, chat, professorship,
# Nearest to there: it, they, often, he, spiritualist, monkey, saltzer, emphases,
# Nearest to also: who, often, brews, not, still, pala, which, heard,
# Nearest to with: between, modernizing, in, alamanni, uematsu, for, by, geologists,
# Nearest to a: classed, any, no, nintendo, occitan, dehydrated, cheetah, aubier,
# Nearest to such: well, known, pesticide, seen, oceanic, many, baggage, these,
# Nearest to can: would, may, could, will, should, might, must, to,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to their: its, his, the, some, our, her, anglicized, trips,
# Nearest to during: shutdown, entire, informers, riley, from, adowa, burdens, before,
# Nearest to be: have, refer, been, binomial, were, stare, broadening, make,
# Nearest to united: sparring, vulva, vied, tremendous, refugees, skilful, blond, front,
# Nearest to i: glockenspiel, ii, p, please, t, polybius, ornamented, experimentation,
# Average loss at step 12000: 3.196533
# Average loss at step 14000: 3.153733
# Average loss at step 16000: 3.172160
# Average loss at step 18000: 3.118983
# Average loss at step 20000: 2.991246
# Nearest to if: when, though, abbas, where, rack, ono, cis, cory,
# Nearest to all: both, khmer, forcing, perceptive, some, cheesemaking, these, transactions,
# Nearest to called: quarks, simile, used, considered, waxes, jacob, stationery, tyson,
# Nearest to new: nile, scientific, auroral, wove, funimation, gift, inlay, alekhine,
# Nearest to there: they, it, often, still, these, usually, he, waco,
# Nearest to also: often, still, sometimes, not, which, ngos, never, now,
# Nearest to with: between, coretta, factual, by, alamanni, urartu, stephens, countable,
# Nearest to a: the, any, classed, every, cartooning, finely, this, kiosks,
# Nearest to such: well, these, known, pesticide, many, endemic, follows, baggage,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to their: its, his, her, the, our, your, anglicized, trips,
# Nearest to during: at, before, in, when, entire, beyond, from, burdens,
# Nearest to be: refer, been, have, being, broadening, is, are, were,
# Nearest to united: vulva, sparring, vied, aberdeen, nirvana, allowance, objectivist, trojan,
# Nearest to i: we, ii, you, he, pipelined, t, abbahu, reflectance,
# Average loss at step 22000: 3.077163
# Average loss at step 24000: 3.040322
# Average loss at step 26000: 3.001454
# Average loss at step 28000: 3.028357
# Average loss at step 30000: 3.009331
# Nearest to if: when, though, where, koto, before, so, augustinians, aneurin,
# Nearest to all: both, some, these, any, mira, parte, mimosa, lucius,
# Nearest to called: used, android, considered, known, tyson, quarks, berger, weekend,
# Nearest to new: nile, third, laurent, pds, alekhine, anarchy, scientific, inlay,
# Nearest to there: they, it, he, she, still, usually, these, often,
# Nearest to also: often, still, now, sometimes, never, actually, which, seldom,
# Nearest to with: between, against, alamanni, diagnostic, when, including, privy, by,
# Nearest to a: the, classed, another, any, kisses, cartooning, opteron, cheetah,
# Nearest to such: well, these, known, many, certain, follows, crypto, described,
# Nearest to can: may, would, could, must, will, should, might, cannot,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to their: its, his, her, the, your, whose, our, trips,
# Nearest to during: in, before, after, when, at, since, under, beyond,
# Nearest to be: refer, been, being, become, have, was, were, inescapable,
# Nearest to united: vied, objectivist, sparring, nirvana, allowance, aberdeen, vulva, inflating,
# Nearest to i: we, abbahu, ii, you, glockenspiel, alden, p, cot,
# Average loss at step 32000: 2.828320
# Average loss at step 34000: 2.956223
# Average loss at step 36000: 2.943919
# Average loss at step 38000: 2.938075
# Average loss at step 40000: 2.937258
# Nearest to if: when, though, where, since, then, symphonic, until, before,
# Nearest to all: both, some, any, many, every, mimosa, perceptive, various,
# Nearest to called: considered, upholds, used, renamed, android, known, featured, salle,
# Nearest to new: inlay, gift, old, marvin, alekhine, badge, nile, marshy,
# Nearest to there: they, he, it, she, usually, often, still, we,
# Nearest to also: still, now, often, actually, never, usually, which, normally,
# Nearest to with: between, during, circumstance, into, in, including, alamanni, joking,
# Nearest to a: another, classed, inlays, paged, boyars, elucidated, any, honeys,
# Nearest to such: well, these, known, follows, seen, certain, pesticide, described,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to their: its, his, her, your, the, our, whose, trips,
# Nearest to during: in, after, before, when, from, since, although, until,
# Nearest to be: being, refer, been, become, have, inescapable, is, cruzi,
# Nearest to united: objectivist, nirvana, city, ellis, czech, vied, sparring, aberdeen,
# Nearest to i: we, you, ii, UNK, iv, p, they, theta,
# Average loss at step 42000: 2.946985
# Average loss at step 44000: 2.964169
# Average loss at step 46000: 2.905094
# Average loss at step 48000: 2.871416
# Average loss at step 50000: 2.850254
# Nearest to if: when, though, where, because, since, symphonic, until, although,
# Nearest to all: both, several, many, various, some, any, every, only,
# Nearest to called: used, upholds, considered, renamed, referred, named, known, lifted,
# Nearest to new: old, different, inlay, badge, contemporary, alekhine, flourishing, marvin,
# Nearest to there: they, it, she, he, we, usually, however, still,
# Nearest to also: actually, now, still, often, seldom, never, sometimes, which,
# Nearest to with: between, urartu, using, circumstance, asch, alamanni, diagnostic, offerings,
# Nearest to a: the, any, another, massawa, aubier, inlays, elucidated, relaxing,
# Nearest to such: well, known, certain, these, follows, many, skaldic, seen,
# Nearest to can: could, may, must, should, would, will, might, cannot,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to their: its, his, her, your, our, whose, these, the,
# Nearest to during: in, after, before, until, since, at, although, from,
# Nearest to be: refer, being, become, been, have, are, refuse, is,
# Nearest to united: city, objectivist, czech, trojan, same, vulva, sparring, aberdeen,
# Nearest to i: we, you, ii, theta, iv, they, iii, abbahu,
# Average loss at step 52000: 2.888414
# Average loss at step 54000: 2.867661
# Average loss at step 56000: 2.858146
# Average loss at step 58000: 2.751322
# Average loss at step 60000: 2.831393
# Nearest to if: when, though, where, since, although, symphonic, whenever, then,
# Nearest to all: both, various, many, several, any, some, each, every,
# Nearest to called: used, considered, named, known, upholds, referred, berger, android,
# Nearest to new: third, flourishing, marshy, postal, previous, badge, particular, inlay,
# Nearest to there: they, it, she, he, still, usually, selfless, we,
# Nearest to also: often, now, still, actually, normally, usually, never, which,
# Nearest to with: between, maas, lockyer, urartu, during, modernizing, factual, lorne,
# Nearest to a: another, the, classed, tvs, harpoon, refresh, glamour, overwriting,
# Nearest to such: well, known, certain, these, follows, crypto, having, regarded,
# Nearest to can: could, should, may, must, would, might, will, cannot,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to their: its, his, her, our, your, the, whose, trips,
# Nearest to during: in, after, when, until, although, within, at, before,
# Nearest to be: been, have, refer, become, being, were, get, parades,
# Nearest to united: ellis, objectivist, uk, nonmetals, trojan, untitled, charterer, coldcut,
# Nearest to i: we, you, g, ii, iii, syntactical, crozier, nz,
# Average loss at step 62000: 2.833150
# Average loss at step 64000: 2.770924
# Average loss at step 66000: 2.762215
# Average loss at step 68000: 2.715678
# Average loss at step 70000: 2.781700
# Nearest to if: when, though, where, since, until, whenever, ret, although,
# Nearest to all: both, various, many, several, some, every, mimosa, perceptive,
# Nearest to called: considered, named, known, upholds, used, referred, charcot, observables,
# Nearest to new: previous, prize, scientific, particular, melodramatic, different, postal, third,
# Nearest to there: they, it, she, he, we, usually, believed, selfless,
# Nearest to also: often, still, now, actually, never, normally, usually, then,
# Nearest to with: between, when, by, including, maas, claypool, freas, asch,
# Nearest to a: the, another, any, classed, finely, every, massless, cartooning,
# Nearest to such: well, known, certain, follows, these, regarded, seen, johore,
# Nearest to can: could, must, may, will, should, might, would, cannot,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to their: its, his, her, our, your, whose, the, my,
# Nearest to during: after, since, in, before, when, although, within, until,
# Nearest to be: been, refer, have, being, become, parades, is, easily,
# Nearest to united: trojan, nonmetals, objectivist, us, ellis, uk, rothbard, untitled,
# Nearest to i: you, we, ii, nz, iii, g, they, mail,
# Average loss at step 72000: 2.801709
# Average loss at step 74000: 2.643165
# Average loss at step 76000: 2.805369
# Average loss at step 78000: 2.822024
# Average loss at step 80000: 2.777672
# Nearest to if: when, though, where, ret, since, whenever, although, homophony,
# Nearest to all: both, various, any, many, several, every, some, rotated,
# Nearest to called: named, known, referred, observables, upholds, considered, used, termed,
# Nearest to new: previous, scientific, different, postal, prize, abol, flourishing, badge,
# Nearest to there: they, it, he, we, she, believed, selfless, said,
# Nearest to also: often, now, actually, still, usually, never, typically, which,
# Nearest to with: between, including, by, fb, in, laterals, denying, gears,
# Nearest to a: another, classed, the, inlays, massless, infraorder, paged, no,
# Nearest to such: well, certain, follows, seen, known, these, endemic, detecting,
# Nearest to can: could, may, must, will, would, might, cannot, should,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to during: after, before, when, in, since, at, within, until,
# Nearest to be: become, refer, been, being, inescapable, easily, have, get,
# Nearest to united: trojan, nonmetals, us, ellis, danish, objectivist, city, german,
# Nearest to i: we, ii, you, they, learns, he, iii, she,
# Average loss at step 82000: 2.666806
# Average loss at step 84000: 2.770249
# Average loss at step 86000: 2.736816
# Average loss at step 88000: 2.753208
# Average loss at step 90000: 2.736513
# Nearest to if: when, though, where, whenever, ret, before, until, homophony,
# Nearest to all: both, various, some, every, many, several, any, rotated,
# Nearest to called: named, known, considered, used, observables, referred, upholds, termed,
# Nearest to new: previous, scientific, gnome, different, flourishing, contemporary, prize, old,
# Nearest to there: they, it, she, we, believed, selfless, he, sometimes,
# Nearest to also: now, still, never, often, actually, always, seldom, currently,
# Nearest to with: between, olin, including, composites, among, fb, mal, holographic,
# Nearest to a: another, classed, inlays, the, opteron, every, aubier, fledged,
# Nearest to such: well, these, follows, known, certain, serve, detecting, act,
# Nearest to can: could, will, may, should, must, might, would, cannot,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to during: after, before, in, throughout, since, when, under, until,
# Nearest to be: become, been, refer, being, get, easily, remain, have,
# Nearest to united: trojan, nonmetals, us, uk, danish, ellis, objectivist, sponsored,
# Nearest to i: we, you, ii, they, iii, iv, fraktion, engineers,
# Average loss at step 92000: 2.679085
# Average loss at step 94000: 2.722318
# Average loss at step 96000: 2.705627
# Average loss at step 98000: 2.365556
# Average loss at step 100000: 2.398725
# Nearest to if: when, though, where, ret, whenever, before, after, operationally,
# Nearest to all: both, various, every, rotated, several, many, some, any,
# Nearest to called: named, used, referred, known, termed, upholds, preferable, consummate,
# Nearest to new: previous, marshy, prize, old, inlay, contemporary, marvin, particular,
# Nearest to there: they, he, she, it, still, we, here, sometimes,
# Nearest to also: still, often, now, actually, never, which, currently, sometimes,
# Nearest to with: between, maas, by, fca, bankruptcies, involving, via, during,
# Nearest to a: overwriting, classed, another, inlays, the, aubier, finely, every,
# Nearest to such: well, known, these, follows, serve, certain, many, opposed,
# Nearest to can: could, will, must, might, cannot, should, may, would,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to during: in, before, after, at, throughout, under, within, despite,
# Nearest to be: become, been, refer, have, being, remain, were, is,
# Nearest to united: trojan, uk, city, us, confederate, nonmetals, danish, nihon,
# Nearest to i: you, ii, we, iii, they, iv, pumped, abbahu,
# CPU times: user 34min 19s, sys: 39.6 s, total: 34min 58s
# Wall time: 35min 30s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# As we can see, CBOW is calculated longer than skip-gram, but it has better quality (average loss).
